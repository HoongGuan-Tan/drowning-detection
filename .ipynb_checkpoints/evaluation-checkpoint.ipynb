# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load metrics from CSV files
kan_rgb_metrics = pd.read_csv("kan_rgb_training_metrics.csv")
kan_gray_metrics = pd.read_csv("kan_grayscale_training_metrics.csv")
cnn_rgb_metrics = pd.read_csv("cnn_rgb_training_metrics.csv")
cnn_gray_metrics = pd.read_csv("cnn_grayscale_training_metrics.csv")

# Get number of epochs from the length of lists
epochs = list(range(1, len(kan_rgb_metrics['train_losses']) + 1))

# %%
# Metric mapping
metrics_map = {
    "train_losses": "Training Loss",
    "val_losses": "Validation Loss",
    "train_accuracies": "Training Accuracy (%)",
    "val_accuracies": "Validation Accuracy (%)",
    "precisions": "Precision",
    "recalls": "Recall",
    "f1_scores": "F1 Score"
}

# %% [markdown]
# ## Performance Metrics Graphs

# %% [markdown]
# ### KAN_RGB vs KAN_Grayscale

# %%
# Create subplots
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12, 16))
axes = axes.flatten()

# Plot each metric
for i, (metric_key, metric_label) in enumerate(metrics_map.items()):
    sns.lineplot(x=epochs, y=kan_rgb_metrics[metric_key], label="RGB", color='red', ax=axes[i], marker='o')
    sns.lineplot(x=epochs, y=kan_gray_metrics[metric_key], label="Grayscale", color='gray', ax=axes[i], marker='s')
    
    axes[i].set_title(metric_label)
    axes[i].set_xlabel("Epoch")
    axes[i].set_ylabel(metric_label)
    axes[i].legend()

# Hide unused subplot (if odd number)
if len(metrics_map) < len(axes):
    fig.delaxes(axes[-1])

plt.tight_layout()
plt.suptitle("Model Metric Comparison (RGB vs Grayscale)", fontsize=16, y=1.02)
plt.savefig("kan_rgbvsgrayscale.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### CNN_RGB vs CNN_Grayscale

# %%
# Create subplots
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12, 16))
axes = axes.flatten()

# Plot each metric
for i, (metric_key, metric_label) in enumerate(metrics_map.items()):
    sns.lineplot(x=epochs, y=cnn_rgb_metrics[metric_key], label="RGB", color='red', ax=axes[i], marker='o')
    sns.lineplot(x=epochs, y=cnn_gray_metrics[metric_key], label="Grayscale", color='gray', ax=axes[i], marker='s')
    
    axes[i].set_title(metric_label)
    axes[i].set_xlabel("Epoch")
    axes[i].set_ylabel(metric_label)
    axes[i].legend()

# Hide unused subplot (if odd number)
if len(metrics_map) < len(axes):
    fig.delaxes(axes[-1])

plt.tight_layout()
plt.suptitle("Model Metric Comparison (RGB vs Grayscale)", fontsize=16, y=1.02)
plt.savefig("cnn_rgbvsgrayscale.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### KAN_RGB vs CNN_RGB

# %%
# Create subplots
fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(12, 16))
axes = axes.flatten()

# Plot each metric
for i, (metric_key, metric_label) in enumerate(metrics_map.items()):
    sns.lineplot(x=epochs, y=kan_rgb_metrics[metric_key], label="KAN", ax=axes[i], marker='o')
    sns.lineplot(x=epochs, y=cnn_rgb_metrics[metric_key], label="CNN", ax=axes[i], marker='s')
    
    axes[i].set_title(metric_label)
    axes[i].set_xlabel("Epoch")
    axes[i].set_ylabel(metric_label)
    axes[i].legend()

# Hide unused subplot (if odd number)
if len(metrics_map) < len(axes):
    fig.delaxes(axes[-1])

plt.tight_layout()
plt.suptitle("Model Metric Comparison (RGB vs Grayscale)", fontsize=16, y=1.02)
plt.savefig("kan_vs_cnn.png", bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Train and Validation Loss

# %%
# Set the plot style
sns.set(style="white")

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 8), sharex=True)

# Plot for KAN_RGB
axes[0].plot(epochs, kan_rgb_metrics["train_losses"], label="Training Loss", color="lightblue", linewidth=2)
axes[0].plot(epochs, kan_rgb_metrics["val_losses"], label="Validation Loss", color="orange", linewidth=2)
axes[0].set_title("Training and Validation Loss in KAN_RGB", fontsize=14)
axes[0].set_ylabel("Loss", fontsize=12)
axes[0].legend()

# Plot for CNN_RGB
axes[1].plot(epochs, cnn_rgb_metrics["train_losses"], label="Training Loss", color="lightblue", linewidth=2)
axes[1].plot(epochs, cnn_rgb_metrics["val_losses"], label="Validation Loss", color="orange", linewidth=2)
axes[1].set_title("Training and Validation Loss in CNN_RGB", fontsize=14)
axes[1].set_xlabel("Epochs", fontsize=12)
axes[1].set_ylabel("Loss", fontsize=12)
axes[1].legend()

# Adjust layout
plt.tight_layout()
plt.savefig('train_val_loss.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Train and Validation Accuracy

# %%
# Set the plot style
sns.set(style="white")

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 8), sharex=True)

# Plot for KAN_RGB
axes[0].plot(epochs, kan_rgb_metrics["train_accuracies"], label="Training Accuracy", color="lightblue", linewidth=2)
axes[0].plot(epochs, kan_rgb_metrics["val_accuracies"], label="Validation Accuracy", color="orange", linewidth=2)
axes[0].set_title("Training and Validation Accuracy in KAN_RGB", fontsize=14)
axes[0].set_ylabel("Accuracy", fontsize=12)
axes[0].legend()

# Plot for CNN_RGB
axes[1].plot(epochs, cnn_rgb_metrics["train_accuracies"], label="Training Accuracy", color="lightblue", linewidth=2)
axes[1].plot(epochs, cnn_rgb_metrics["val_accuracies"], label="Validation Accuracy", color="orange", linewidth=2)
axes[1].set_title("Training and Validation Accuracy in CNN_RGB", fontsize=14)
axes[1].set_xlabel("Epochs", fontsize=12)
axes[1].set_ylabel("Accuracy", fontsize=12)
axes[1].legend()

# Adjust layout
plt.tight_layout()
plt.savefig('train_val_accuracy.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Confusion Matrix and Classification Report

# %%
# Imnport Libraries
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision.transforms import transforms
import torchvision
from torch.utils.data import Dataset, DataLoader

# KAN library
from kan_convolutional.KANConv import KAN_Convolutional_Layer
from kan_convolutional.KANLinear import KANLinear

from sklearn.metrics import classification_report, confusion_matrix
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from tqdm import tqdm

# %%
class DrowningDataset(Dataset):
    def __init__(self, csv_file, split, transform=None):
        self.annotations = pd.read_csv(csv_file)
        self.annotations = self.annotations[self.annotations['file_path'].str.contains(rf'\\{split}\\|/{split}/', regex=True)]
        self.transform = transform

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, index):
        img_path = self.annotations.iloc[index, 0]

        # Use PIL to open image
        image = Image.open(img_path).convert("RGB")  
        y_label = torch.tensor(int(self.annotations.iloc[index, 1]))

        if self.transform:
            image = self.transform(image)

        return image, y_label

# %%
val_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

val_ds = DrowningDataset(csv_file = 'drowning_dataset_32.csv', split = 'val', transform = val_transform)
val_loader = DataLoader(dataset=val_ds, batch_size=32, shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### KAN_RGB

# %%
class KAN_RGB(nn.Module):
    def __init__(self, grid_size: int = 5):
        super().__init__()
        self.conv1 = KAN_Convolutional_Layer(in_channels=3,
            out_channels= 6,
            kernel_size= (5,5),
            grid_size = grid_size,
            padding =(0,0)
        )

        self.conv2 = KAN_Convolutional_Layer(in_channels=6,
            out_channels= 16,
            kernel_size = (5,5),
            grid_size = grid_size,
            padding =(0,0)
        )

        self.pool1 = nn.MaxPool2d(
            kernel_size=(2, 2)
        )
        
        self.flat = nn.Flatten() 

        self.kan1 = KANLinear(
            400,
            3,
            grid_size=grid_size,
            spline_order=3,
            scale_noise=0.01,
            scale_base=1,
            scale_spline=1,
            base_activation=nn.SiLU,
            grid_eps=0.02,
            grid_range=[0,1],
        )

    def forward(self, x):
        x = self.conv1(x)
        x = self.pool1(x)
        
        x = self.conv2(x)
        x = self.pool1(x)
        
        x = self.flat(x)
        x = self.kan1(x)

        return x

kan_model = KAN_RGB()

# %%
# Load kan_rgb model
kan_model.load_state_dict(torch.load('kan_rgb_model.pth'))
kan_model.to(device)
kan_model.eval()

kan_all_preds, kan_all_labels = [], []

with torch.no_grad():
    for (images, labels) in tqdm(val_loader):
        images, kan_labels = images.to(device), labels.to(device)
        outputs = kan_model(images)
        kan_preds = torch.argmax(outputs, dim=1)

        kan_all_preds.extend(kan_preds.cpu().numpy())
        kan_all_labels.extend(kan_labels.cpu().numpy())

kan_all_preds = np.array(kan_all_preds)
kan_all_labels = np.array(kan_all_labels)
# Out:
# 100%|██████████| 114/114 [00:33<00:00,  3.40it/s]

# %%
kan_cm = confusion_matrix(kan_all_labels, kan_all_preds)
class_names = ['swimming', 'tread_water', 'drowning']

plt.figure(figsize=(8, 6))
sns.heatmap(kan_cm, annot=True, fmt='d', cmap='Purples', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('KAN Confusion Matrix')
plt.savefig("kan_confusion_matrix.png", bbox_inches='tight')
plt.show()

# %%
kan_report = classification_report(kan_all_labels, kan_all_preds, target_names=class_names, digits=4)
print("KAN_RGB Classification Report:\n")
print(kan_report)
# Out:
# KAN_RGB Classification Report:
#
#               precision    recall  f1-score   support
#
#     swimming     0.9898    0.9841    0.9869      1381
#  tread_water     0.9552    0.9702    0.9626      1142
#     drowning     0.9733    0.9644    0.9688      1095
#
#     accuracy                         0.9737      3618
#    macro avg     0.9727    0.9729    0.9728      3618
# weighted avg     0.9739    0.9737    0.9738      3618

# %% [markdown]
# ### CNN_RGB

# %%
class CNN_RGB(nn.Module):
    def __init__(self):
        super(CNN_RGB, self).__init__()

        # Convolutional layers
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=6, kernel_size=5, padding=0)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, padding=0)

        # Pooling layer
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # Fully connected layers
        self.flat = nn.Flatten()
        self.fc1 = nn.Linear(16 * 5 * 5, 3)  # Flattened size = 400, output = 3

        # Activation
        self.activation = nn.SiLU()

    def forward(self, x):
        x = self.pool(F.silu(self.conv1(x)))  
        x = self.pool(F.silu(self.conv2(x)))  
        x = self.flat(x)
        x = self.fc1(x)
        x = F.log_softmax(x, dim=1)  

        return x

cnn_model = CNN_RGB()

# %%
# Load kan_rgb model
cnn_model.load_state_dict(torch.load('cnn_rgb_model.pth'))
cnn_model.to(device)
cnn_model.eval()

cnn_all_preds, cnn_all_labels = [], []

with torch.no_grad():
    for (images, labels) in tqdm(val_loader):
        images, cnn_labels = images.to(device), labels.to(device)
        outputs = cnn_model(images)
        cnn_preds = torch.argmax(outputs, dim=1)

        cnn_all_preds.extend(cnn_preds.cpu().numpy())
        cnn_all_labels.extend(cnn_labels.cpu().numpy())

cnn_all_preds = np.array(cnn_all_preds)
cnn_all_labels = np.array(cnn_all_labels)
# Out:
# 100%|██████████| 114/114 [00:02<00:00, 56.47it/s]

# %%
cnn_cm = confusion_matrix(cnn_all_labels, cnn_all_preds)
class_names = ['swimming', 'tread_water', 'drowning']

plt.figure(figsize=(8, 6))
sns.heatmap(cnn_cm, annot=True, fmt='d', cmap='Reds', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('CNN Confusion Matrix')
plt.savefig("cnn_confusion_matrix.png", bbox_inches='tight')
plt.show()

# %%
cnn_report = classification_report(cnn_all_labels, cnn_all_preds, target_names=class_names, digits=4)
print("CNN Classification Report:\n")
print(cnn_report)
# Out:
# CNN Classification Report:
#
#               precision    recall  f1-score   support
#
#     swimming     0.9805    0.9833    0.9819      1381
#  tread_water     0.9348    0.9545    0.9445      1142
#     drowning     0.9644    0.9397    0.9519      1095
#
#     accuracy                         0.9610      3618
#    macro avg     0.9599    0.9592    0.9595      3618
# weighted avg     0.9612    0.9610    0.9610      3618
