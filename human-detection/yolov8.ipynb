# %%
# !nvidia-smi
# Out:
# Sat Apr  5 23:38:17 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 561.19                 Driver Version: 561.19         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce MX550         WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   54C    P8              2W /   30W |       0MiB /   2048MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\jojoa\OneDrive\Desktop\Image Processing

# %%
# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.90  Python-3.12.2 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce MX550, 2048MiB)
# Setup complete  (12 CPUs, 15.7 GB RAM, 570.0/930.4 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="J4GBEVQIb0l43qzIo8Pi")
project = rf.workspace("boom-ry3lr").project("my-first-project-1mwb3")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import torch
torch.cuda.empty_cache()

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")  # Load the YOLOv8 model

# Train the model
results = model.train(
    data=f"{dataset.location}/data.yaml",  
    epochs=25,                             
    imgsz=640,                             
    batch=8,                               
    project='human-detection-project',     
    name='yolov8s-human',                  
    exist_ok=True                          
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.102 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.90  Python-3.12.2 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce MX550, 2048MiB)
# ...

# %%
# Save model to desired path
model_path = 'yolov8s-human.pt'
model.save(model_path)
print(f"Model saved to: {model_path}")
# Out:
# Model saved to: yolov8s-human.pt
